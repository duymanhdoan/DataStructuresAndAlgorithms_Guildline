# %% [markdown]
# ## I. Giới thiệu phép toán cơ bản về python.
# ### A. Phần chi tiết.
# #### 1.1 Cài đặt Python và các thư viện cần thiết:
#
#    - [Windows](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/essential-installs/vn-windows-python-and-libraries-installations.MD)
#        -  Python
#        -  Pip
#        -  Jupyter Notebook
#        -  TensorFlow
#        -  Annaconda
#    - [Mac](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/essential-installs/vn-mac-python-and-libraries-installations.MD)
#        -  Python
#        -  Pip
#        -  Jupyter Notebook
#
# #### 1.2. sử dụng python.
# - [nhập, xuất trong python](https://phannhatchanh.com/python-input-output/)
# - [phép gán, phép nhân/chia/cộng/trừ](https://o2.edu.vn/cac-phep-toan-trong-python/)
#
# #### 1.3. kiểu dữ liệu
# - [int, float, bool](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/integer-float-boolean.ipynb)
# - [String](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/string.ipynb)
#
# #### 1.4. vòng lặp và câu lệnh if.
#
# - [câu lệnh if else](https://quantrimang.com/lenh-if-ifelse-trong-python-141111)
#
# - [Vòng lặp for và while ](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/loop.ipynb)
# - [for với index](https://stackabuse.com/how-to-access-index-in-pythons-for-loop/?fbclid=IwAR0iscmds0leegi8nHyl_OZbWCvMw-XzCBH8Lws9XZonN6Pi7CoGo16K6uk)
# - [hàm range funtion](https://www.codehub.com.vn/Python-Co-Ban/Vong-Lap)
# - [lệnh break, continues](https://quantrimang.com/lenh-break-va-continue-trong-python-142623)
# - [lệnh pass](https://quantrimang.com/lenh-pass-trong-python-143045)
#
# #### 1.5. định nghĩa hàm
# - [function(hàm) ](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/function.ipynb)
#
# - [hàm vô danh (lamda)](https://quantrimang.com/ham-vo-danh-lambda-trong-python-146099)
#
# - chú thích phần này: Hàm trong python bắt đầu bằng từ khóa def. Trong python cũng chia ra hàm có giá trị trả về và hàm không có giá trị trả về. Hàm có đối số truyền vào, và hàm không có đối số truyền vào. Nhưng hàm python có ưu điểm hơn là có thể trả về cùng lúc nhiều giá trị, với giá trị có nhiều kiểu dữ liệu khác nhau. Rất linh hoạt, thuận tiện và dễ dùng.
#
# #### 1.6. cấu trúc dữ liệu
#
# - [List](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/list.ipynb)
#     - List Comprehensions (Phần nâng cao hơn của list một dạng code ngắn hơn trong list) [tham khảo](https://quantrimang.com/cach-su-dung-list-comprehension-trong-python-154301)
#
#
# - [Tuples](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/tuple.ipynb)
#
# - [Set](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/set.ipynb)
#
# - [Dictionaries](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/dictionary.ipynb)
#
# #### 1.7. modules (nâng cao)
# - [tham khảo](https://docs.python.org/3/tutorial/modules.html) :
#     - modules
#         + thực thi modules với file.py và tham số.
#         + thực thi model tìm kiếm dường dẫn
#         + thực thi modul khỏi tạo file compiled, ý nghĩa file compiled.
#     - Chuẩn định nghĩa modules.
#     - Hàm dir(), cách dùng, ý nghĩa.
#     - Gói, thư viện (packages)
#         + import thư viện tự tạo
#         + tham chiếu thưc viện
#         + nhiều gói, thư viện.
#
# #### 1.8. định nghĩa input và ouput (nâng cao)
# - [tham khảo](https://docs.python.org/3/tutorial/inputoutput.html)
#     - fancier ouput formatting.
#         + formatting string method.
#     - đọc và ghi vào file.
#         + phương thức của file đối tượng.
#         + lưu cấu truc dữ liệu dạng file json.
#
# #### 1.9. Error và  eceptions. (nâng cao)
# - [tham khảo](https://docs.python.org/3/tutorial/errors.html)
#
# #### 1.10. classes
# - [tham khảo](https://docs.python.org/3/tutorial/classes.html)
#
# ### B. Phần tóm tắt + bài tập
# - [tham khảo code ở đây](https://github.com/duymanhdoan/Guildline_ML/blob/master/Introduction_overview_python.ipynb)
#
# ### C. Nguồn tham khảo.
# 1. [khóa học ML của anh Ngọc](https://github.com/bangoc123/learn-machine-learning-in-two-months)
# 2. [documentation python](https://docs.python.org/3/tutorial/index.html)

# %% [markdown]
# #### Bài Tập
#
# - [Bài tập phần dictionary](https://github.com/duymanhdoan/Guildline_ML/blob/master/BT_Dictionary.pdf)
#
# - [Bài tập phần hàm](https://github.com/duymanhdoan/Guildline_ML/blob/master/BT_Function.pdf)
#
# - [Slide và bài tập phân list và tuple](https://github.com/duymanhdoan/Guildline_ML/blob/master/List_Tuple.pdf)
#
# - [Slide và bài tập phần Dictionary và Function](https://github.com/duymanhdoan/Guildline_ML/blob/master/Dictionary_Function.pdf)
#
# - [Slide và bài tập phần vòng lặp for và String](https://github.com/duymanhdoan/Guildline_ML/blob/master/for_va_string.pdf)

# %% [markdown]
# ## II + III + VII Các phép toán cơ bản với numpy, Numpy với mảng, Indexing & Slicing
#
# #### 1.1 Numpy là gì
#
# - [bài viết tiếng việt tổng quan về numpy khá dễ hiểu ](https://viblo.asia/p/python-numpy-tutorial-hoc-numpy-arrays-voi-cac-vi-du-ORNZqjPnl0n)
# - [Giải thích numpy](https://viblo.asia/p/tim-hieu-ve-thu-vien-numpy-trong-pythonphan-1-Do7542QXZM6)
#     + numpy là gì?
#     + mục đích ?
#     + tại sao numpy tốc độ xử lý nhanh.
# #### 1.2. Numpy cơ bản.
# - [Data Types](https://jakevdp.github.io/PythonDataScienceHandbook/02.01-understanding-data-types.html)
#     + giới thiệu kiểu dữ liệu
#     + [khỏi tạo mảng Tiếng việt](https://vncoder.vn/bai-hoc/quy-trinh-tao-mang-472)
#     + [kiểu dữ liệu tiếng việt](https://vncoder.vn/bai-hoc/kieu-du-lieu-470)
# - [The Basics](https://jakevdp.github.io/PythonDataScienceHandbook/02.02-the-basics-of-numpy-arrays.html)
#     + truy cập theo chỉ số mảng
#     + cắt mảng (mảng 1D, 2D, 3D...)
#     + tạo mảng sao chép
#     + reshape mảng.
#     + gộp mảng thành mảng to từ mảng con, tách mảng to từ mảng con
#     + [thuộc tính của mảng tiếng việt](https://vncoder.vn/bai-hoc/thuoc-tinh-cua-mang-471)
# - [Universal Functions](https://jakevdp.github.io/PythonDataScienceHandbook/02.03-computation-on-arrays-ufuncs.html)
#     + giới thiệu universal func
#     + các phép toán số học với mảng (*, /, + , -)
#     + hàm trị tuyệt đối, dấu âm.
#     + hàm lượng giác
#     + số mũ và logarit
#     + phép nhân 2 mảng.
# - [Broadcasting](https://jakevdp.github.io/PythonDataScienceHandbook/02.05-computation-on-arrays-broadcasting.html)
#     + giới thiệu về Broadcasting ( phép toán scalar với array)
#     + quy tắc phép toán scalar với array ( rule of broadcasting)
#     + ví dụ tạo mảng.
# - [Comparisons, Masks, and Boolean Logic](https://jakevdp.github.io/PythonDataScienceHandbook/02.06-boolean-arrays-and-masks.html)
#     + giới thiệu, chức năng toán tử so sánh
#     + thao thác với mảng bool
#     + đếm với mảng bool
#     + các hoạt động so sánh với mảng bool
#     + đánh dấu mảng bool
#     + sử dụng phép and, or, xor , toán tử bit
# - [Fancy Indexing](https://jakevdp.github.io/PythonDataScienceHandbook/02.07-fancy-indexing.html)
#     + khám phá facy indexing
#     + kết hợp truy cập nhiều index cùng lúc.
#     + gán lại giá trị mảng với nhiều vị trí
#     + [Indexing & Slicing](https://www.pythoninformer.com/python-libraries/numpy/index-and-slice/)
# - [Sorting Arrays](https://jakevdp.github.io/PythonDataScienceHandbook/02.08-sorting.html)
#     + sắp xếp tối ưu hơn với numpy
#     + sắp xếp theo cột, hàng
#     + tìm k giá trị nhỏ nhất của mảng (1D, 2D)
# - [Min, Max, and Everything In Between](https://jakevdp.github.io/PythonDataScienceHandbook/02.04-computation-on-arrays-aggregates.html)
#     + tính tổng giá trị trong 1 mảng
#     + tìm giá trị lớn nhất, nhỏ nhất trong mảng.
#     + kết hợp tính tổng, giá trị lớn nhất nhỏ nhất trong mảng nhiều chiều.
#
# - [giới thiệu numpy với mảng](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/numpy/array.ipynb)
#
# #### 1.3 Nguồn tham khảo
# - [sách (Python Data Science Handbook)](https://jakevdp.github.io/PythonDataScienceHandbook/)
# - [docunemtation numpy](https://numpy.org/doc/stable/user/index.html)

# %% [markdown]
# ## III + IV+ VIII + IX. Pandas cấu trúc dữ liệu và phân tích dữ liệu, DataFrame
#
# #### Seri
# - [Phần seri ](https://vimentor.com/vi/lesson/3-khoi-tao-va-truy-cap-voi-du-lieu-kieu-series-trong-pandas)
# - [sự khác nhau của seri và dataframe](https://vncoder.vn/bai-hoc/gioi-thieu-ve-cau-truc-du-lieu-524)
#
# #### Dataframe
#
# - [Creating, Reading and Writing](https://www.kaggle.com/residentmario/creating-reading-and-writing)
#
# - [Indexing, Selecting & Assigning](https://www.kaggle.com/residentmario/indexing-selecting-assigning)
#
# - [Summary Functions and Maps](https://www.kaggle.com/residentmario/summary-functions-and-maps)
#
# - [Grouping and Sorting](https://www.kaggle.com/residentmario/grouping-and-sorting)
#
# - [Data Types and Missing Values](https://www.kaggle.com/residentmario/data-types-and-missing-values)
#
# - [Renaming and Combining](https://www.kaggle.com/residentmario/renaming-and-combining)
#
# #### Ý nghĩa.
#
# - ý nghĩa của dataframe trong pandas để  phục vụ cho 2 bước [feature engineering](https://www.kaggle.com/learn/feature-engineering) và [Cleaning](https://www.kaggle.com/learn/data-cleaning)
#
# - Dataframe ứng dụng vào xử lý dữ liệu dưới dạng file excel ví dụ như (clearning data, handle missing value, feature engineering ... vv). Ngoài ra, dataframe còn giúp xử lý dữ liệu dạng date time.
#
# - Qúa trình xử lý dữ liệu trước đó để phục vụ cho từng bài toán tùy vào yêu cầu. Có thể để mô hình hóa dữ liệu hoặc để huấn luyện mô hình học máy.

# %% [markdown]
# ## V + VI. Unsupervised  và Supervised learning với Tensorflow.
#
#
#  -
#
#  -
#
#  -

# %% [markdown]
# ## X. Hiển thị dữ liệu với Matplotlib, Seabon.
#
# #### [Data Visualization](https://www.kaggle.com/learn/data-visualization)
#
#  - [Seaborn](https://www.kaggle.com/alexisbcook/hello-seaborn)
#
#  - [Line Charts](https://www.kaggle.com/alexisbcook/line-charts)
#
#  - [Bar Charts and Heatmaps](https://www.kaggle.com/alexisbcook/bar-charts-and-heatmaps)
#
#  - [Scatter Plots](https://www.kaggle.com/alexisbcook/scatter-plots)
#
#  - [Distributions](https://www.kaggle.com/alexisbcook/distributions)
#
#  -
