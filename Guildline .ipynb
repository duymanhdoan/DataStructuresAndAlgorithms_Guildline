# %% [markdown]
# ## I. Giới thiệu phép toán cơ bản về python.
# ### A. Phần chi tiết.
# #### 1.1 Cài đặt Python và các thư viện cần thiết:
#
#    - [Windows](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/essential-installs/vn-windows-python-and-libraries-installations.MD)
#        -  Python
#        -  Pip
#        -  Jupyter Notebook
#        -  TensorFlow
#        -  Annaconda
#    - [Mac](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/essential-installs/vn-mac-python-and-libraries-installations.MD)
#        -  Python
#        -  Pip
#        -  Jupyter Notebook
#
# #### 1.2. sử dụng python.
# - [nhập, xuất trong python](https://phannhatchanh.com/python-input-output/)
# - [phép gán, phép nhân/chia/cộng/trừ](https://o2.edu.vn/cac-phep-toan-trong-python/)
#
# #### 1.3. kiểu dữ liệu
# - [int, float, bool](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/integer-float-boolean.ipynb)
# - [String](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/string.ipynb)
#
# #### 1.4. vòng lặp và câu lệnh if.
#
# - [câu lệnh if else](https://quantrimang.com/lenh-if-ifelse-trong-python-141111)
#
# - [Vòng lặp for và while ](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/loop.ipynb)
# - [hàm range funtion](https://www.codehub.com.vn/Python-Co-Ban/Vong-Lap)
# - [lệnh break, continues](https://quantrimang.com/lenh-break-va-continue-trong-python-142623)
# - [lệnh pass](https://quantrimang.com/lenh-pass-trong-python-143045)
#
# #### 1.5. định nghĩa hàm
# - [function(hàm) ](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/function.ipynb)
#
# - [hàm vô danh (lamda)](https://quantrimang.com/ham-vo-danh-lambda-trong-python-146099)
#
# - chú thích phần này: Hàm trong python bắt đầu bằng từ khóa def. Trong python cũng chia ra hàm có giá trị trả về và hàm không có giá trị trả về. Hàm có đối số truyền vào, và hàm không có đối số truyền vào. Nhưng hàm python có ưu điểm hơn là có thể trả về cùng lúc nhiều giá trị, với giá trị có nhiều kiểu dữ liệu khác nhau. Rất linh hoạt, thuận tiện và dễ dùng.
#
# #### 1.6. cấu trúc dữ liệu
#
# - [List](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/list.ipynb)
#     - List Comprehensions (Phần nâng cao hơn của list một dạng code ngắn hơn trong list) [tham khảo](https://quantrimang.com/cach-su-dung-list-comprehension-trong-python-154301)
#
#
# - [Tuples](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/tuple.ipynb)
#
# - [Set](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/set.ipynb)
#
# - [Dictionaries](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/python-tutorials/dictionary.ipynb)
#
# #### 1.7. modules (nâng cao)
# - [tham khảo](https://docs.python.org/3/tutorial/modules.html) :
#     - modules
#         + thực thi modules với file.py và tham số.
#         + thực thi model tìm kiếm dường dẫn
#         + thực thi modul khỏi tạo file compiled, ý nghĩa file compiled.
#     - Chuẩn định nghĩa modules.
#     - Hàm dir(), cách dùng, ý nghĩa.
#     - Gói, thư viện (packages)
#         + import thư viện tự tạo
#         + tham chiếu thưc viện
#         + nhiều gói, thư viện.
#
# #### 1.8. định nghĩa input và ouput (nâng cao)
# - [tham khảo](https://docs.python.org/3/tutorial/inputoutput.html)
#     - fancier ouput formatting.
#         + formatting string method.
#     - đọc và ghi vào file.
#         + phương thức của file đối tượng.
#         + lưu cấu truc dữ liệu dạng file json.
#
# #### 1.9. Error và  eceptions. (nâng cao)
# - [tham khảo](https://docs.python.org/3/tutorial/errors.html)
#
# #### 1.10. classes
# - [tham khảo](https://docs.python.org/3/tutorial/classes.html)
#
# ### B. Phần tóm tắt + bài tập
# - [tham khảo code ở đây](https://github.com/duymanhdoan/Guildline_ML/blob/master/Introduction_overview_python.ipynb)
#
# ### C. Nguồn tham khảo.
# 1. [khóa học ML của anh Ngọc](https://github.com/bangoc123/learn-machine-learning-in-two-months)
# 2. [documentation python](https://docs.python.org/3/tutorial/index.html)

# %% [markdown]
# #### Bài Tập
#
# - [Bài tập phần dictionary](https://github.com/duymanhdoan/Guildline_ML/blob/master/BT_Dictionary.pdf)
#
# - [Bài tập phần hàm](https://github.com/duymanhdoan/Guildline_ML/blob/master/BT_Function.pdf)
#
# - [Slide và bài tập phân list và tuple](https://github.com/duymanhdoan/Guildline_ML/blob/master/List_Tuple.pdf)
#
# - [Slide và bài tập phần Dictionary và Function](https://github.com/duymanhdoan/Guildline_ML/blob/master/Dictionary_Function.pdf)
#
# - [Slide và bài tập phần vòng lặp for và String](https://github.com/duymanhdoan/Guildline_ML/blob/master/for_va_string.pdf)

# %% [markdown]
# ## II. Các phép toán cơ bản với numpy (chưa hoàn thành)
#
# - The Basics
# - Shape Manipulation
# - Copies and Views
# - Less Basic
# - Advanced indexing and index tricks
# - Linear Algebra
# - Tricks and Tips
# - Further reading
#
# https://numpy.org/doc/stable/user/quickstart.html

# %% [markdown]
# ## III. Numpy với mảng (chưa hoàn thành)
#
# - 3.1 [giới thiệu numpy với mảng](https://github.com/bangoc123/learn-machine-learning-in-two-months/blob/master/numpy/array.ipynb)
#
#
# ### Nguồn tham khảo
# - https://github.com/bangoc123/learn-machine-learning-in-two-months/tree/master/numpy
# - https://numpy.org/doc/stable/user/quickstart.html
